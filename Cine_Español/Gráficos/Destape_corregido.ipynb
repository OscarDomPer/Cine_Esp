# %% [markdown]
# ##Destape

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import folium

# %%
# Cargar los datos
df = pd.read_csv("data/data_peliculas_transformado_filtrado.csv")
df.head()
# Out:
#                         Título  \
# 0                   El verdugo
# 1         Los santos inocentes
# 2                      Plácido
# 3                    Viridiana
# 4  Bienvenido, Míster Marshall
#
#                                                URL Procesado  Nota    Votos  \
# 0  https://www.filmaffinity.com/es/film411856.html        Sí   8.2  41447.0
# 1  https://www.filmaffinity.com/es/film879812.html        Sí   8.1  44470.0
# 2  https://www.filmaffinity.com/es/film895672.html        Sí   8.1  20396.0
# 3  https://www.filmaffinity.com/es/film123112.html        Sí   8.1  28771.0
# 4  https://www.filmaffinity.com/es/film435869.html        Sí   8.0  31421.0
#
#           Año                                            Reparto  \
# 0  1963-01-01  ['José Isbert', 'Nino Manfredi', 'Emma Penella...
# 1  1984-01-01  ['Alfredo Landa', 'Francisco Rabal', 'Juan Die...
# 2  1961-01-01  ['Cassen', 'José Luis López Vázquez', 'Elvira ...
# 3  1961-01-01  ['Silvia Pinal', 'Fernando Rey', 'Francisco Ra...
# 4  1953-01-01  ['José Isbert', 'Lolita Sevilla', 'Manolo Morá...
#
#                    Director                       Compañías  \
# 0  ['Luis García Berlanga']   ['Naga Films', 'Zabra Films']
# 1           ['Mario Camus']              ['Ganesh', 'RTVE']
# 2  ['Luis García Berlanga']  ['Jet Films', 'Alfredo Matas']
# 3           ['Luis Buñuel']          ['Films 59', 'Uninci']
# 4  ['Luis García Berlanga']                      ['Uninci']
#
#         Coproducción                                            Géneros  \
# 0  ['España-Italia']  ['Comedia', 'Sátira', 'Comedia negra', 'Pelícu...
# 1                 []  ['Drama', 'Drama social', 'Vida rural', 'Años ...
# 2                 []        ['Comedia', 'Pobreza', 'Navidad', 'Sátira']
# 3  ['España-México']         ['Drama', 'Religión', 'Película de culto']
# 4                 []                              ['Comedia', 'Sátira']
#
#                                              Premios  Presupuesto   Ingresos  \
# 0    ['1963: Festival de Venecia: Premios FIPRESCI']          0.0        0.0
# 1  ['1984: Cannes: Mejor Actor (ex aequo: Francis...          0.0  3149062.0
# 2  ['1961: Nominada al Oscar: Mejor película de h...          0.0        0.0
# 3  ['1961: Festival de Cannes: Palma de Oro (ex-a...          0.0   679244.0
# 4  ['1953: Festival de Cannes: Premio Internacion...          0.0        0.0
#
#    Protagonistas
# 0    José Isbert
# 1  Alfredo Landa
# 2         Cassen
# 3   Silvia Pinal
# 4    José Isbert

# %%
# Definir la función para aplicar el estilo estándar a las gráficas
def apply_standard_style(plot):
    sns.set_style("whitegrid")
    plot.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
    plot.set_axisbelow(True)
    plot.set_xlabel(plot.get_xlabel(), fontsize=12, weight='bold')
    plot.set_ylabel(plot.get_ylabel(), fontsize=12, weight='bold')
    plot.set_title(plot.get_title(), fontsize=14, weight='bold')
    for tick in plot.get_xticklabels():
        tick.set_rotation(45)
        tick.set_fontsize(10)
        tick.set_weight('bold')
    for tick in plot.get_yticklabels():
        tick.set_fontsize(10)
        tick.set_weight('bold')
    plt.tight_layout()

# Función para añadir sombreado de fondo y líneas divisorias con anotaciones verticales
def add_background_shading_and_dividers(plot):
    # Definir los períodos y sus etiquetas
    periods = [
        (1900, 1936, 'Etapa inicial: 1900 a 1936'),
        (1936, 1960, 'Primera etapa del Franquismo: 1936 a 1960'),
        (1960, 1975, 'Segunda Etapa del Franquismo: 1960 a 1975'),
        (1975, 1983, 'Destape: 1975 a 1983'),
        (1983, 2007, 'Periodo: 1983 a 2007'),
        (2007, 2020, 'Crisis Financiera: 2007 a 2020'),
        (2020, 2023, 'Pandemia Covid: 2020 a 2023')
    ]
    
    # Colores para el sombreado de fondo
    colors = ['#DDEEFF', '#AACCFF', '#77AAFF', '#4488FF', '#1166FF', '#0044FF', '#0022BB']
    
    # Aplicar el sombreado de fondo y las anotaciones
    for i, (start, end, label) in enumerate(periods):
        color = colors[i % len(colors)]
        plot.axvspan(start, end, color=color, alpha=0.1)
        mid_point = (start + end) / 2
        ylim = plot.get_ylim()
        vertical_position = ylim[0] + (ylim[1] - ylim[0]) / 2
        plot.text(mid_point, vertical_position, label, ha='center', va='center', rotation='vertical', color='grey', alpha=0.7)

# Convertir 'Año' a tipo datetime y extraer el año
df['Año'] = pd.to_datetime(df['Año'], errors='coerce')
df.dropna(subset=['Año'], inplace=True)  # Eliminar filas con fechas inválidas
df['Año'] = df['Año'].dt.year

# Gráfico 1: Número de Películas por Año
plt.figure(figsize=(14, 7))
data = df['Año'].value_counts().sort_index()
plot = sns.lineplot(x=data.index, y=data.values, color='blue')
plot.set_title('Número de Películas por Año')

# Rellenar debajo de la línea con color azul
plt.fill_between(data.index, data.values, color='blue', alpha=0.09)

# Aplicar estilo, sombreado de fondo y líneas divisorias
add_background_shading_and_dividers(plot)
apply_standard_style(plot)
plt.show()

# Gráfico 2: Número de Películas de Género "Cine Quinqui" y Política por Año
plt.figure(figsize=(14, 7))
peliculas_social = df[df['Géneros'].str.contains('Cine quinqui', case=False, na=False)]
peliculas_politica = df[df['Géneros'].str.contains('Política', case=False, na=False)]
peliculas_social_por_año = peliculas_social['Año']
peliculas_politica_por_año = peliculas_politica['Año']

# Definir los bins con ancho de 5 años
bins = list(range(min(peliculas_social_por_año.min(), peliculas_politica_por_año.min()), max(peliculas_social_por_año.max(), peliculas_politica_por_año.max()) + 6, 5))

plot = sns.histplot(data=peliculas_social_por_año, bins=bins, kde=True, color='blue', label='Cine quinqui')
plot = sns.histplot(data=peliculas_politica_por_año, bins=bins, kde=True, color='darkblue', label='Política')
plot.set_title('Número de Películas de Género "Cine quinqui" y Política por Año (Histograma)')
plot.set_xlabel('Año')
plot.set_ylabel('Frecuencia')

# Aplicar estilo, sombreado de fondo y líneas divisorias
add_background_shading_and_dividers(plt.gca())
apply_standard_style(plt.gca())

# Añadir título
plot.set_title('Número de Películas de Género "Cine quinqui" y Política por Año')

# Establecer el rango deseado en el eje x
plot.set_xlim(1900, max(peliculas_social_por_año.max(), peliculas_politica_por_año.max()))

plt.legend()
plt.show()


# Gráfico 3: Número de Películas Eróticas por Año (como histograma)
plt.figure(figsize=(14, 7))
peliculas_eroticas = df[df['Géneros'].str.contains('Erótico', case=False, na=False)]
peliculas_eroticas_por_año = peliculas_eroticas['Año']
plot = sns.histplot(data=peliculas_eroticas_por_año, bins=15, kde=True, color='blue')
plot.set_title('Número de Películas Eróticas por Año (Histograma)')

# Aplicar estilo, sombreado de fondo y líneas divisorias
add_background_shading_and_dividers(plot)
apply_standard_style(plot)
plt.show()

# %%
# Filtrar películas de género "Cine quinqui" entre 1974 y 1985
filtered_movies = df[(df['Año'] >= 1974) & (df['Año'] <= 1985) & (df['Géneros'].str.contains('Cine quinqui', case=False, regex=True))]

# Calcular la ponderación
filtered_movies['Ponderacion'] = filtered_movies['Nota'] * filtered_movies['Votos']

# Ordenar las películas por ponderación en orden descendente y seleccionar las tres principales
top_weighted_movies = filtered_movies.sort_values(by='Ponderacion', ascending=False).head(3)

# Mostrar las tres películas principales con sus títulos, años y géneros
top_weighted_movies[['Título', 'Año', 'Géneros']]
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_9828\3610771184.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_movies['Ponderacion'] = filtered_movies['Nota'] * filtered_movies['Votos']
#                                   Título   Año  \
# 81   ¿Qué he hecho yo para merecer esto!  1984
# 187                              El pico  1983
# 310                     Deprisa, deprisa  1981
#
#                                                Géneros
# 81   ['Comedia', 'Drama', 'Comedia negra', 'Familia...
# 187  ['Drama', 'Drogas', 'Adolescencia', 'Cine quin...
# 310  ['Drama', 'Crimen', 'Adolescencia', 'Robos & A...

# %%
# Filtrar películas de género erótico entre 1947 y 1990
filtered_movies = df[(df['Año'] >= 1974) & (df['Año'] <= 1985) & (df['Géneros'].str.contains('Erótico', case=False, regex=True))]

# Calcular la ponderación
filtered_movies['Ponderacion'] = filtered_movies['Nota'] * filtered_movies['Votos']

# Ordenar las películas por ponderación en orden descendente y seleccionar las tres principales
top_weighted_movies = filtered_movies.sort_values(by='Ponderacion', ascending=False).head(3)

# Mostrar las tres películas principales con sus títulos, años y géneros
top_weighted_movies[['Título', 'Año', 'Géneros']]
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_7400\5915820.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_movies['Ponderacion'] = filtered_movies['Nota'] * filtered_movies['Votos']
#              Título   Año                 Géneros
# 2364  La trastienda  1975    ['Drama', 'Erótico']
# 1508     Escalofrío  1978   ['Terror', 'Erótico']
# 2497       La orgía  1978  ['Comedia', 'Erótico']

# %%
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_7400\709537384.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_movies_musical['Ponderacion'] = filtered_movies_musical['Nota'] * filtered_movies_musical['Votos']
#              Título   Año                 Géneros
# 2364  La trastienda  1975    ['Drama', 'Erótico']
# 1508     Escalofrío  1978   ['Terror', 'Erótico']
# 2497       La orgía  1978  ['Comedia', 'Erótico']
